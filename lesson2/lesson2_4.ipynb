# %%
chinese = 78
chinese = chinese + 5
english = 92
math = 67
total = chinese + english + math

average = total / 3
average
# Out:
# 80.66666666666667

# %%
# 複合指定運算子
import math

chinese = 78
chinese += 5
chinese *= 10

# chinese 開平方根
value = math.sqrt(chinese)
value = round(value,ndigits=2)

# %%
# 複合運算子
import math

chinese = 78
chinese += 5
chinese *= 10

# chinese 開平方根
math.sqrt(chinese)
round(math.sqrt(chinese),ndigits=2)
# Out:
# 28.81
